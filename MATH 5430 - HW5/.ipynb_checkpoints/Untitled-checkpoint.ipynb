# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import math
from itertools import combinations

# %%
boston = pd.read_csv("boston.csv")
boston.head(6)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# 5     18.7  394.12   5.21  28.7

# %%
# Out:
# 0.15078046904975717

# %%
def get_uni_R2(X, y=boston["MEDV"]):
    return LinearRegression().fit(X.values.reshape(-1, 1), 
                                  y.values).score(X.values.reshape(-1, 1), y.values)

unilr_r2 = {}
for col in boston.columns:
    unilr_r2[col] = get_uni_R2(boston[col])
unilr_r2.pop("MEDV")
unilr_r2 = pd.Series(unilr_r2)
unilr_r2[unilr_r2.values == max(unilr_r2)]
# Out:
# LSTAT    0.544146
# dtype: float64

# %%
np.square(np.subtract(LinearRegression().fit(boston["LSTAT"].values.reshape(-1, 1), boston["MEDV"].values
                                            ).predict(boston["LSTAT"].values.reshape(-1, 1)), 
                      boston["MEDV"].values))
# Out:
# array([3.39026137e+01, 1.82362289e+01, 1.57994962e+01, 2.68731833e+00,
#        4.50230556e+01, 8.17367420e-01, 2.41095765e-02, 1.15339099e+02,
#        1.07767990e+02, 3.50467635e-01, 1.57080087e-02, 9.28229531e+00,
#        4.29084076e+00, 3.97710999e+01, 4.36436557e+01, 4.36514296e+01,
#        2.70661741e+01, 9.71330065e+00, 1.05479706e+01, 3.17789728e+01,
#        9.67869255e-01, 3.29298481e+00, 2.46150048e+00, 1.36156162e+00,
#        1.20272766e+01, 2.46862511e+01, 1.50824262e+01, 1.11354892e+01,
#        1.59457193e+01, 4.71866842e+00, 1.46478796e-01, 5.87552497e+01,
#        2.47210496e+01, 1.61638995e+01, 2.99233613e+00, 4.16975387e+01,
#        1.37921452e+01, 2.72683237e+01, 5.28268512e-02, 1.22760769e-01,
#        4.96067304e+00, 1.12600648e+01, 1.39431603e+01, 7.75886366e+00,
#        1.83258441e+01, 3.08451052e+01, 1.23352682e+00, 8.63283091e-03,
#        8.31229659e+01, 5.61494025e-02, 4.30843530e+00, 2.59577561e+01,
# ...

# %%
# Out:
# array([29.8225951 , 25.87038979, 30.72514198, 31.76069578, 29.49007782,
#        29.60408375, 22.74472741, 16.36039575,  6.11886372, 18.30799693,
#        15.1253316 , 21.94668596, 19.62856553, 26.70643322, 24.80633451,
#        26.50692285, 28.30251613, 20.61661686, 23.44776393, 23.83728417,
#        14.58380346, 21.41465832, 16.76891698, 15.66685973, 19.06803641,
#        18.86852605, 20.48360995, 18.13698805, 22.39320915, 23.17224962,
#        13.08272548, 22.16519731,  8.22797329, 17.12043524, 15.22983702,
#        25.35736314, 23.71377775, 26.22190805, 24.92984093, 30.44962767,
#        32.67274316, 29.95560201, 29.03405413, 27.48547369, 25.48086955,
#        24.85383698, 21.11064252, 16.69291303,  5.28282029, 19.16304135,
#        21.77567707, 25.59487547, 29.53758029, 26.54492483, 20.49311044,
#        29.98410349, 29.07205611, 30.80114593, 28.03650231, 25.79438584,
#        22.06069188, 20.83512821, 28.16000873, 25.52837202, 26.90594358,
# ...

# %% [markdown]
# LSTAT would provide best predictive power in univariate linear regression.

# %%
feature_lst = list(boston.columns)
feature_lst.remove("MEDV")
feature_lst
two_feature_comb = list(combinations(feature_lst, 2))

# %%
def get_multi2_R2(comb, y=boston["MEDV"]):
    X = boston[[comb[0], comb[1]]]
    return LinearRegression().fit(X.values, y.values).score(X.values, y.values)

multi2_r2 = {}
for comb in two_feature_comb:
    multi2_r2[comb] = get_multi2_R2(comb)
multi2_r2 = pd.Series(multi2_r2)
multi2_r2[multi2_r2.values == max(multi2_r2)]
# Out:
# RM  LSTAT    0.638562
# dtype: float64

# %% [markdown]
# By

# %%
# Out:
# LSTAT      0.544146
# RM         0.483525
# PTRATIO    0.257847
# INDUS      0.233990
# TAX        0.219526
# NOX        0.182603
# CRIM       0.150780
# RAD        0.145639
# AGE        0.142095
# ZN         0.129921
# B          0.111196
# DIS        0.062464
# CHAS       0.030716
# dtype: float64
