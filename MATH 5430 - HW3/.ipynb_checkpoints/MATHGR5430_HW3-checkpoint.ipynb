# %% [markdown]
# # Machine Learning for Finance Homework 3

# %% [markdown]
# In this homework, we will focus on
#
# 1.   Sentiment Analysis using NLP
# 2.   Clustering with KMeans++, Inertia, PCA and short EDA
# 3.   Individual project proposal

# %% [markdown]
# ## 1. Pre-trained model: FinBERT

# %% [markdown]
# Your hedge fund manager wakes up every morning at 4am and wants a concise summary of the news relevant to his portfolio. He/She wants a quick summary showing the headlines of the news as well as classified sentiment scores.
#
# Furthermore, he/she asks you to aggregate this information per stock and summarize the overall tone for this stock

# %% [markdown]
# 1.1 Install the transformers package

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\tianj\anaconda3\lib\site-packages (4.17.0)
# Requirement already satisfied: sacremoses in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (0.0.49)
# Requirement already satisfied: filelock in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (3.4.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (0.11.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tianj\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tianj\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tianj\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\tianj\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tianj\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tianj\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tianj\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tianj\anaconda3\lib\site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: click in c:\users\tianj\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: joblib in c:\users\tianj\anaconda3\lib\site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in c:\users\tianj\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1.2 import the requests package and other libraries you might need

# %%
import pandas as pd
import requests

# %% [markdown]
# The following dictionary represents our portfolio of stocks using the following logic (key, value) = (holding-name, branch), where $$branch ∈ \{"business", "entertainment", "general", "health", "science", "sports", "tech
# nology"\}$$
# following the NewsAPI documentation.
#
# To save you some time, a typical request is built similar to:
# "https://newsapi.org/v2/top-headlines?country=us&q=*KEYWORD*&category=*CATEGORY*&sortBy=top&apiKey=*YOURKEYHERE*".
#
# For example:
#
# https://newsapi.org/v2/top-headlines?country=us&q=apple&category=technology&sortBy=top&apiKey=123ab45c687d...
#
#
#
#
#
# Please see:
#
#
# 1.   https://newsapi.org/docs (To construct your HTTP GET-requests)
# 2.   https://newsapi.org/register (To obtain your API key)

# %%
portfolio = dict({"apple": 'technology', "tesla": 'business', "amazon": 'technology', "s&p500": 'business'})

# we are going to use the S&P500 to get a general idea of the sentiment of news in the US market

# %% [markdown]
# 1.3 Write the function fetch_news() that returns a dictionary that stores the name of the holding as key (analogous to our stock portfolio) and as value an array that holds the strings of news

# %%
# This is my api_key
api_key = "1fa2671224264342a6af4a9cc19c8eb8"

def fetch_news():
    result = {}
    for keyword in portfolio.keys():
        request_str = "https://newsapi.org/v2/top-headlines?country=us&q=" + \
                    keyword + "&category=" + portfolio.get(keyword) + \
                    "&sortBy=top&apiKey=" + api_key
        result[keyword] = [dic.get("title") \
                           for dic in requests.get(request_str).json().get("articles")]
    return result

# %%
fetch_news()
# Out:
# {'apple': ['Pixel Notepad & Pixel Watch: New default for Android users avoiding iPad, Galaxy Z Fold, Apple Watch - PhoneArena',
#   'Gurman: MacBook Air Delayed to Second Half of 2022, No New High-End MacBook Pro Likely Until Next Year - MacRumors',
#   'iPad Air 5 is great, but here’s why it’s not an M1 iPad Pro replacement - 9to5Mac',
#   'Does Apple (AAPL) Sell a Wireless Router? What Happened to the Apple AirPort? - Bloomberg',
#   'Everything we know so far about the Apple Silicon 27-inch iMac replacement - 9to5Mac',
#   'Tile Adds Anti-Stalking Feature Following Apple AirTag Controversy - Breitbart',
#   'The weekend’s best deals: Apple Watch Series 7, gift card bundles, and more - Ars Technica',
#   "Tim Cook responds to thank you note after Apple Watch saves dentist's life - AppleInsider",
#   'Apple’s M1 Ultra Gets Murdered by AMD’s Threadrippers: Slower than NVIDIA’s RTX 3050 in ... - Hardware Times',
#   "The iPhone SE 5G is a tempting buy since Apple won't give me what I want - Android Central",
#   'Apple iPhone users complain: "iOS 15.4 update is draining my batteries rapidly" - PhoneArena'],
#  'tesla': ['Reward offered for information on driver who jumped Tesla in Echo Park - KTLA Los Angeles',
#   'Tesla Giga Berlin receives full approval to begin production and delivery of customer cars - Drive Tesla Canada'],
#  'amazon': [],
#  's&p500': ['Thoma Bravo to Buy Anaplan for $10.7 Billion - The Wall Street Journal',
#   'Chevron begins replacing workers ahead of California refinery strike - Reuters.com',
#   "Hong Kong's Hang Seng pares gains as Asia stocks rise; oil jumps about 3% - CNBC",
#   'Reward offered for information on driver who jumped Tesla in Echo Park - KTLA Los Angeles',
#   "5 Retail Stocks That Can Shine in a Slowdown - Barron's",
#   "Stock futures are steady after S&P 500's best week since 2020 - CNBC",
#   'Recall: Jergens Ultra Healing Moisturizer recalled for harmful bacteria Pluralibacter gergoviae - KABC-TV',
#   'Wisconsin gas stations sue competitor for having cheaper gas prices - WOODTV.com',
#   'End the week with Playmakers at a 40-percent discount - ProFootballTalk',
#   "Woman sought for questioning in fatal shooting near NYC Dunkin' - New York Post ",
#   'Ethereum Co-Founder: Ukraine-Russia War Setting Stage for Mainstream Crypto Adoption - CryptoGlobe',
#   "Meta employees look to ditch jobs amid stock crash: 'Feeling like s--t' - New York Post ",
#   "This Week on Crypto Twitter: Elon Musk's Diamond Hands, Tom Brady Responds to Vitalik - Decrypt",
#   'Bitcoin (BTC) Supply on Crypto Exchanges Drops to Three-Year Lows, According to Analytics Firm - The Daily Hodl',
#   'Airlines are passing on fuel price hikes to travelers as demand rebounds - AOL',
#   'Nike earnings, consumer sentiment: What to know in markets this week - Yahoo Finance',
#   'LME: Nickel Squeeze Threatens London Metal Exchange - Bloomberg',
#   'Here’s A Sneak Peek At The 2023 BMW i7 Electric Sedan With A 305-Mile EPA Range - CarScoops',
#   "Big food automation is making its way to Main Street's menu - CNBC",
#   'Canadian Pacific Railway Work Stoppage Threatens New Supply-Chain Snarl - The Wall Street Journal']}

# %% [markdown]
# 1.4 Following the lecture notes, using the pre-trained Finbert Classifier, classify the news fetched in 1.3 into neutral, positive or negative by modifying the below code:

# %% [markdown]
# 1.5 Last but not least, find the total tone for each element in our portfolio, where:
#
#
# *   neutral=0
# *   positive=+1
# *   negative=-1

# %%
# BUILD YOUR CODE ON TOP OF THIS EXAMPLE CODE IN THE CELL BELOW
from transformers import BertTokenizer, BertForSequenceClassification
import numpy as np

finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

sentences = ["there is a shortage of capital, and we need extra financing", 
             "growth is strong and we have plenty of liquidity", 
             "there are doubts about our finances", 
             "profits are flat"]

inputs = tokenizer(sentences, return_tensors="pt", padding=True)
outputs = finbert(**inputs)[0]

labels = {0:'neutral', 1:'positive',2:'negative'}
for idx, sent in enumerate(sentences):
    print(sent, '----', labels[np.argmax(outputs.detach().numpy()[idx])])
    
'''
there is a shortage of capital, and we need extra financing ---- negative
growth is strong and we have plenty of liquidity ---- positive
there are doubts about our finances ---- negative
profits are flat ---- neutral
'''
# Out:
# there is a shortage of capital, and we need extra financing ---- negative
# growth is strong and we have plenty of liquidity ---- positive
# there are doubts about our finances ---- negative
# profits are flat ---- neutral
# '\nthere is a shortage of capital, and we need extra financing ---- negative\ngrowth is strong and we have plenty of liquidity ---- positive\nthere are doubts about our finances ---- negative\nprofits are flat ---- neutral\n'

# %%
# Your code here
import re

# Define a function to remove the author name at the end of each title.
def parseSentence(sen: str) -> str:
    return re.split("[\s]-[\s]", sen)[0]

classified_news = {}
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone', 
                                                        num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
labels = {0:'neutral', 1:'positive', 2:'negative'}

for company in fetch_news().keys():
    classified_news[company] = []
    sentences = list(map(parseSentence, fetch_news().get(company)))
    if not sentences:
        continue
    else:
        inputs = tokenizer(sentences, return_tensors="pt", padding=True)
        outputs = finbert(**inputs)[0]
        for idx, sent in enumerate(sentences):
            classified_news[company].append(sent + '----' + \
                            labels[np.argmax(outputs.detach().numpy()[idx])])
classified_news
# Out:
# {'apple': ['Pixel Notepad & Pixel Watch: New default for Android users avoiding iPad, Galaxy Z Fold, Apple Watch----neutral',
#   'Gurman: MacBook Air Delayed to Second Half of 2022, No New High-End MacBook Pro Likely Until Next Year----negative',
#   'iPad Air 5 is great, but here’s why it’s not an M1 iPad Pro replacement----positive',
#   'Does Apple (AAPL) Sell a Wireless Router? What Happened to the Apple AirPort?----neutral',
#   'Everything we know so far about the Apple Silicon 27-inch iMac replacement----neutral',
#   'Tile Adds Anti-Stalking Feature Following Apple AirTag Controversy----negative',
#   'The weekend’s best deals: Apple Watch Series 7, gift card bundles, and more----neutral',
#   "Tim Cook responds to thank you note after Apple Watch saves dentist's life----neutral",
#   'Apple’s M1 Ultra Gets Murdered by AMD’s Threadrippers: Slower than NVIDIA’s RTX 3050 in ...----negative',
#   "The iPhone SE 5G is a tempting buy since Apple won't give me what I want----neutral",
#   'Apple iPhone users complain: "iOS 15.4 update is draining my batteries rapidly"----negative'],
#  'tesla': ['Reward offered for information on driver who jumped Tesla in Echo Park----neutral',
#   'Tesla Giga Berlin receives full approval to begin production and delivery of customer cars----positive'],
#  'amazon': [],
#  's&p500': ['Thoma Bravo to Buy Anaplan for $10.7 Billion----neutral',
#   'Chevron begins replacing workers ahead of California refinery strike----neutral',
#   "Hong Kong's Hang Seng pares gains as Asia stocks rise; oil jumps about 3%----positive",
#   'Reward offered for information on driver who jumped Tesla in Echo Park----neutral',
#   '5 Retail Stocks That Can Shine in a Slowdown----positive',
#   "Stock futures are steady after S&P 500's best week since 2020----positive",
#   'Recall: Jergens Ultra Healing Moisturizer recalled for harmful bacteria Pluralibacter gergoviae----neutral',
#   'Wisconsin gas stations sue competitor for having cheaper gas prices----neutral',
#   'End the week with Playmakers at a 40-percent discount----neutral',
#   "Woman sought for questioning in fatal shooting near NYC Dunkin'----neutral",
#   'Ethereum Co-Founder: Ukraine-Russia War Setting Stage for Mainstream Crypto Adoption----neutral',
#   "Meta employees look to ditch jobs amid stock crash: 'Feeling like s--t'----positive",
#   "This Week on Crypto Twitter: Elon Musk's Diamond Hands, Tom Brady Responds to Vitalik----neutral",
#   'Bitcoin (BTC) Supply on Crypto Exchanges Drops to Three-Year Lows, According to Analytics Firm----negative',
#   'Airlines are passing on fuel price hikes to travelers as demand rebounds----positive',
#   'Nike earnings, consumer sentiment: What to know in markets this week----neutral',
#   'LME: Nickel Squeeze Threatens London Metal Exchange----negative',
#   'Here’s A Sneak Peek At The 2023 BMW i7 Electric Sedan With A 305-Mile EPA Range----neutral',
#   "Big food automation is making its way to Main Street's menu----neutral",
#   'Canadian Pacific Railway Work Stoppage Threatens New Supply-Chain Snarl----negative']}

# %%
# Your code here
tone_dic = {"neutral": 0, "positive": 1, "negative": -1}
total_tone = 0
for company in classified_news.keys():
    for sentence in classified_news.get(company):
        total_tone += tone_dic.get(re.split("----", sentence)[1])
total_tone
# Out:
# 0

# %% [markdown]
# ## 2. K-Means++ Clustering with PCA
#
# ---
#
# To make it easier for you, for the analysis important EDA has already been performed. However, it is your task to interpret

# %% [markdown]
# 2.1 Import necessary libraries...

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans
import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# 2.2 Read the credit card data into a dataframe

# %%
cc_holders = pd.read_csv("credit_card.csv")

# %% [markdown]
# 2.3 Show a snippet of the dataframe

# %%
cc_holders
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %% [markdown]
# 2.4 Gather information about missing data, data type and the dimensions of the dataset

# %%
cc_holders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# 2.5 Gather statistical measures about each column

# %%
cc_holders.describe().style.background_gradient(cmap = 'twilight')
# Out:
# <style type="text/css">
# #T_16514_row0_col0 {
#   background-color: #381145;
#   color: #f1f1f1;
# }
# #T_16514_row0_col1, #T_16514_row0_col6, #T_16514_row0_col7, #T_16514_row0_col8, #T_16514_row0_col9, #T_16514_row0_col10, #T_16514_row0_col11, #T_16514_row0_col15, #T_16514_row0_col16, #T_16514_row1_col1, #T_16514_row1_col6, #T_16514_row1_col7, #T_16514_row1_col8, #T_16514_row1_col9, #T_16514_row1_col10, #T_16514_row1_col11, #T_16514_row1_col15, #T_16514_row1_col16, #T_16514_row2_col1, #T_16514_row2_col6, #T_16514_row2_col7, #T_16514_row2_col8, #T_16514_row2_col9, #T_16514_row2_col10, #T_16514_row2_col15, #T_16514_row2_col16, #T_16514_row3_col0, #T_16514_row3_col1, #T_16514_row3_col2, #T_16514_row3_col3, #T_16514_row3_col4, #T_16514_row3_col5, #T_16514_row3_col6, #T_16514_row3_col7, #T_16514_row3_col8, #T_16514_row3_col9, #T_16514_row3_col10, #T_16514_row3_col11, #T_16514_row3_col12, #T_16514_row3_col13, #T_16514_row3_col14, #T_16514_row3_col15, #T_16514_row3_col16, #T_16514_row4_col1, #T_16514_row4_col2, #T_16514_row4_col3, #T_16514_row4_col4, #T_16514_row4_col5, #T_16514_row4_col6, #T_16514_row4_col7, #T_16514_row4_col8, #T_16514_row4_col9, #T_16514_row4_col10, #T_16514_row4_col11, #T_16514_row4_col15, #T_16514_row4_col16, #T_16514_row5_col1, #T_16514_row5_col3, #T_16514_row5_col5, #T_16514_row5_col6, #T_16514_row5_col7, #T_16514_row5_col8, #T_16514_row5_col9, #T_16514_row5_col10, #T_16514_row5_col11, #T_16514_row5_col15, #T_16514_row5_col16, #T_16514_row6_col1, #T_16514_row6_col6, #T_16514_row6_col7, #T_16514_row6_col8, #T_16514_row6_col9, #T_16514_row6_col10, #T_16514_row6_col11, #T_16514_row6_col15, #T_16514_row6_col16, #T_16514_row7_col0, #T_16514_row7_col1, #T_16514_row7_col2, #T_16514_row7_col3, #T_16514_row7_col4, #T_16514_row7_col5, #T_16514_row7_col6, #T_16514_row7_col7, #T_16514_row7_col8, #T_16514_row7_col9, #T_16514_row7_col12, #T_16514_row7_col13, #T_16514_row7_col14, #T_16514_row7_col15, #T_16514_row7_col16 {
#   background-color: #e2d9e2;
#   color: #000000;
# }
# #T_16514_row0_col2 {
#   background-color: #7499c1;
#   color: #f1f1f1;
# }
# #T_16514_row0_col3 {
#   background-color: #6887be;
#   color: #f1f1f1;
# }
# #T_16514_row0_col4 {
#   background-color: #551f7f;
#   color: #f1f1f1;
# }
# #T_16514_row0_col5 {
#   background-color: #7196c1;
#   color: #f1f1f1;
# }
# #T_16514_row0_col12 {
#   background-color: #5f5ab1;
#   color: #f1f1f1;
# }
# #T_16514_row0_col13 {
#   background-color: #779dc2;
#   color: #f1f1f1;
# }
# #T_16514_row0_col14 {
#   background-color: #9dbac8;
#   color: #000000;
# }
# #T_16514_row1_col0 {
#   background-color: #b5c7cf;
#   color: #000000;
# }
# #T_16514_row1_col2, #T_16514_row1_col5, #T_16514_row6_col4 {
#   background-color: #dcd9df;
#   color: #000000;
# }
# #T_16514_row1_col3, #T_16514_row6_col3, #T_16514_row7_col10 {
#   background-color: #ded9e1;
#   color: #000000;
# }
# #T_16514_row1_col4 {
#   background-color: #dcd9e0;
#   color: #000000;
# }
# #T_16514_row1_col12 {
#   background-color: #86aac4;
#   color: #f1f1f1;
# }
# #T_16514_row1_col13 {
#   background-color: #d5d6dc;
#   color: #000000;
# }
# #T_16514_row1_col14, #T_16514_row6_col14 {
#   background-color: #dfd9e1;
#   color: #000000;
# }
# #T_16514_row2_col0, #T_16514_row6_col0 {
#   background-color: #a0bcc9;
#   color: #000000;
# }
# #T_16514_row2_col2, #T_16514_row2_col5 {
#   background-color: #d0d4d9;
#   color: #000000;
# }
# #T_16514_row2_col3, #T_16514_row2_col4, #T_16514_row7_col11 {
#   background-color: #d2d5db;
#   color: #000000;
# }
# #T_16514_row2_col11, #T_16514_row4_col14, #T_16514_row5_col4, #T_16514_row5_col14 {
#   background-color: #e1d9e2;
#   color: #000000;
# }
# #T_16514_row2_col12 {
#   background-color: #97b7c7;
#   color: #000000;
# }
# #T_16514_row2_col13 {
#   background-color: #c7d0d5;
#   color: #000000;
# }
# #T_16514_row2_col14 {
#   background-color: #d7d7dd;
#   color: #000000;
# }
# #T_16514_row4_col0, #T_16514_row4_col13, #T_16514_row5_col2 {
#   background-color: #e0d9e2;
#   color: #000000;
# }
# #T_16514_row4_col12 {
#   background-color: #cbd2d7;
#   color: #000000;
# }
# #T_16514_row5_col0 {
#   background-color: #ced3d9;
#   color: #000000;
# }
# #T_16514_row5_col12 {
#   background-color: #a7c0cb;
#   color: #000000;
# }
# #T_16514_row5_col13 {
#   background-color: #ddd9e0;
#   color: #000000;
# }
# #T_16514_row6_col2 {
#   background-color: #dbd8df;
#   color: #000000;
# }
# #T_16514_row6_col5 {
#   background-color: #dad8df;
#   color: #000000;
# }
# #T_16514_row6_col12 {
#   background-color: #6989be;
#   color: #f1f1f1;
# }
# #T_16514_row6_col13 {
#   background-color: #d3d6db;
#   color: #000000;
# }
# </style>
# <table id="T_16514">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16514_level0_col0" class="col_heading level0 col0" >BALANCE</th>
#       <th id="T_16514_level0_col1" class="col_heading level0 col1" >BALANCE_FREQUENCY</th>
#       <th id="T_16514_level0_col2" class="col_heading level0 col2" >PURCHASES</th>
#       <th id="T_16514_level0_col3" class="col_heading level0 col3" >ONEOFF_PURCHASES</th>
#       <th id="T_16514_level0_col4" class="col_heading level0 col4" >INSTALLMENTS_PURCHASES</th>
#       <th id="T_16514_level0_col5" class="col_heading level0 col5" >CASH_ADVANCE</th>
#       <th id="T_16514_level0_col6" class="col_heading level0 col6" >PURCHASES_FREQUENCY</th>
#       <th id="T_16514_level0_col7" class="col_heading level0 col7" >ONEOFF_PURCHASES_FREQUENCY</th>
#       <th id="T_16514_level0_col8" class="col_heading level0 col8" >PURCHASES_INSTALLMENTS_FREQUENCY</th>
#       <th id="T_16514_level0_col9" class="col_heading level0 col9" >CASH_ADVANCE_FREQUENCY</th>
#       <th id="T_16514_level0_col10" class="col_heading level0 col10" >CASH_ADVANCE_TRX</th>
#       <th id="T_16514_level0_col11" class="col_heading level0 col11" >PURCHASES_TRX</th>
#       <th id="T_16514_level0_col12" class="col_heading level0 col12" >CREDIT_LIMIT</th>
#       <th id="T_16514_level0_col13" class="col_heading level0 col13" >PAYMENTS</th>
#       <th id="T_16514_level0_col14" class="col_heading level0 col14" >MINIMUM_PAYMENTS</th>
#       <th id="T_16514_level0_col15" class="col_heading level0 col15" >PRC_FULL_PAYMENT</th>
#       <th id="T_16514_level0_col16" class="col_heading level0 col16" >TENURE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16514_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_16514_row0_col0" class="data row0 col0" >8950.000000</td>
#       <td id="T_16514_row0_col1" class="data row0 col1" >8950.000000</td>
#       <td id="T_16514_row0_col2" class="data row0 col2" >8950.000000</td>
#       <td id="T_16514_row0_col3" class="data row0 col3" >8950.000000</td>
#       <td id="T_16514_row0_col4" class="data row0 col4" >8950.000000</td>
#       <td id="T_16514_row0_col5" class="data row0 col5" >8950.000000</td>
#       <td id="T_16514_row0_col6" class="data row0 col6" >8950.000000</td>
#       <td id="T_16514_row0_col7" class="data row0 col7" >8950.000000</td>
#       <td id="T_16514_row0_col8" class="data row0 col8" >8950.000000</td>
#       <td id="T_16514_row0_col9" class="data row0 col9" >8950.000000</td>
#       <td id="T_16514_row0_col10" class="data row0 col10" >8950.000000</td>
#       <td id="T_16514_row0_col11" class="data row0 col11" >8950.000000</td>
#       <td id="T_16514_row0_col12" class="data row0 col12" >8949.000000</td>
#       <td id="T_16514_row0_col13" class="data row0 col13" >8950.000000</td>
#       <td id="T_16514_row0_col14" class="data row0 col14" >8637.000000</td>
#       <td id="T_16514_row0_col15" class="data row0 col15" >8950.000000</td>
#       <td id="T_16514_row0_col16" class="data row0 col16" >8950.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16514_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_16514_row1_col0" class="data row1 col0" >1564.474828</td>
#       <td id="T_16514_row1_col1" class="data row1 col1" >0.877271</td>
#       <td id="T_16514_row1_col2" class="data row1 col2" >1003.204834</td>
#       <td id="T_16514_row1_col3" class="data row1 col3" >592.437371</td>
#       <td id="T_16514_row1_col4" class="data row1 col4" >411.067645</td>
#       <td id="T_16514_row1_col5" class="data row1 col5" >978.871112</td>
#       <td id="T_16514_row1_col6" class="

# %% [markdown]
# 2.6 Examine the correlation value for each column with each other column

# %%
cc_holders.corr().style.background_gradient(cmap = 'RdYlGn')
# Out:
# <style type="text/css">
# #T_0d6b9_row0_col0, #T_0d6b9_row1_col1, #T_0d6b9_row2_col2, #T_0d6b9_row3_col3, #T_0d6b9_row4_col4, #T_0d6b9_row5_col5, #T_0d6b9_row6_col6, #T_0d6b9_row7_col7, #T_0d6b9_row8_col8, #T_0d6b9_row9_col9, #T_0d6b9_row10_col10, #T_0d6b9_row11_col11, #T_0d6b9_row12_col12, #T_0d6b9_row13_col13, #T_0d6b9_row14_col14, #T_0d6b9_row15_col15, #T_0d6b9_row16_col16 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col1, #T_0d6b9_row1_col9, #T_0d6b9_row2_col0, #T_0d6b9_row4_col3, #T_0d6b9_row4_col15, #T_0d6b9_row12_col13, #T_0d6b9_row13_col10 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_0d6b9_row0_col2, #T_0d6b9_row15_col2, #T_0d6b9_row16_col8 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_0d6b9_row0_col3, #T_0d6b9_row0_col4, #T_0d6b9_row1_col2, #T_0d6b9_row1_col4, #T_0d6b9_row8_col7, #T_0d6b9_row11_col12, #T_0d6b9_row16_col15 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col5, #T_0d6b9_row8_col11, #T_0d6b9_row9_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_0d6b9_row0_col6, #T_0d6b9_row5_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col7, #T_0d6b9_row3_col14 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col8 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col9, #T_0d6b9_row11_col3 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_0d6b9_row0_col10 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_0d6b9_row0_col11, #T_0d6b9_row7_col12 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col12 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_0d6b9_row0_col13, #T_0d6b9_row13_col8 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_0d6b9_row0_col14, #T_0d6b9_row6_col15 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_0d6b9_row0_col15, #T_0d6b9_row1_col13, #T_0d6b9_row6_col5, #T_0d6b9_row6_col9, #T_0d6b9_row6_col10, #T_0d6b9_row9_col2, #T_0d6b9_row9_col3, #T_0d6b9_row9_col4, #T_0d6b9_row9_col6, #T_0d6b9_row9_col7, #T_0d6b9_row9_col8, #T_0d6b9_row9_col11, #T_0d6b9_row9_col16, #T_0d6b9_row15_col0, #T_0d6b9_row15_col1, #T_0d6b9_row15_col12, #T_0d6b9_row15_col14 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0d6b9_row0_col16, #T_0d6b9_row3_col1, #T_0d6b9_row6_col0, #T_0d6b9_row8_col16 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_0d6b9_row1_col0, #T_0d6b9_row13_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_0d6b9_row1_col3, #T_0d6b9_row3_col9, #T_0d6b9_row3_col16, #T_0d6b9_row6_col16, #T_0d6b9_row12_col1, #T_0d6b9_row16_col7, #T_0d6b9_row16_col14 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_0d6b9_row1_col5, #T_0d6b9_row11_col1, #T_0d6b9_row14_col10, #T_0d6b9_row15_col11 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_0d6b9_row1_col6 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_0d6b9_row1_col7, #T_0d6b9_row1_col11, #T_0d6b9_row12_col15, #T_0d6b9_row16_col6 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_0d6b9_row1_col8 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_0d6b9_row1_col10 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_0d6b9_row1_col12, #T_0d6b9_row6_col13 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_0d6b9_row1_col14, #T_0d6b9_row4_col14, #T_0d6b9_row12_col16 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_0d6b9_row1_col15, #T_0d6b9_row14_col16 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_0d6b9_row1_col16, #T_0d6b9_row11_col16, #T_0d6b9_row16_col11 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col1, #T_0d6b9_row9_col14, #T_0d6b9_row11_col14, #T_0d6b9_row14_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col3, #T_0d6b9_row3_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col4, #T_0d6b9_row5_col9, #T_0d6b9_row10_col5 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_0d6b9_row2_col5, #T_0d6b9_row4_col9, #T_0d6b9_row11_col9, #T_0d6b9_row14_col15, #T_0d6b9_row16_col3, #T_0d6b9_row16_col9, #T_0d6b9_row16_col10 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col6, #T_0d6b9_row3_col13 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_0d6b9_row2_col7, #T_0d6b9_row13_col5 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_0d6b9_row2_col8, #T_0d6b9_row6_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_0d6b9_row2_col9 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col10, #T_0d6b9_row7_col10, #T_0d6b9_row10_col15 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col11, #T_0d6b9_row11_col2 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_0d6b9_row2_col12, #T_0d6b9_row13_col7 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_0d6b9_row2_col13 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_0d6b9_row2_col14, #T_0d6b9_row10_col13 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_0d6b9_row2_col15, #T_0d6b9_row13_col9 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_0d6b9_row2_col16, #T_0d6b9_row4_col16, #T_0d6b9_row8_col0, #T_0d6b9_row8_col3, #T_0d6b9_row16_col4 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_0d6b9_row3_col0, #T_0d6b9_row11_col15, #T_0d6b9_row12_col7 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_0d6b9_row3_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_0d6b9_row3_col5, #T_0d6b9_row7_col9, #T_0d6b9_row8_col14 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_0d6b9_row3_col6 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_0d6b9_row3_col7, #T_0d6b9_row4_col6 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_0d6b9_row3_col8, #T_0d6b9_row14_col9 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_0d6b9_row3_col10 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_0d6b9_row3_col11, #T_0d6b9_row13_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_0d6b9_row3_col12, #T_0d6b9_row15_col4 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_0d6b9_row3_col15, #T_0d6b9_row4_col13, #T_0d6b9_row12_col4 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_0d6b9_row4_col0, #T_0d6b9_row12_col9 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_0d6b9_row4_col1, #T_0d6b9_row14_col11 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_0d6b9_row4_col2, #T_0d6b9_row5_col10 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_0d6b9_row4_col5, #T_0d6b9_row14_col3, #T_0d6b9_row16_col5 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_0d6b9_row4_col7, #T_0d6b9_row6_col1, #T_0d6b9_row12_col10 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_0d6b9_row4_col8 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_0d6b9_row4_col10, #T_0d6b9_row7_col5 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_0d6b9_row4_col11, #T_0d6b9_row11_col4, #T_0d6b9_row11_col6 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_0d6b9_row4_col12, #T_0d6b9_row13_col16 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col0, #T_0d6b9_row6_col11, #T_0d6b9_row7_col6 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_0d6b9_row5_col2, #T_0d6b9_row5_col4 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col3, #T_0d6b9_row5_col11, #T_0d6b9_row10_col2, #T_0d6b9_row15_col13 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col6, #T_0d6b9_row14_col7 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col7, #T_0d6b9_row8_col13 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col8, #T_0d6b9_row6_col12 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col12, #T_0d6b9_row9_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_0d6b9_row5_col13 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_0d6b9_row5_col14, #T_0d6b9_row15_col7 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col15, #T_0d6b9_row6_col14, #T_0d6b9_row9_col13 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_0d6b9_row5_col16, #T_0d6b9_row10_col11 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_0d6b9_row6_col3, #T_0d6b9_row7_col8 {
#   background-color

# %% [markdown]
# 2.7 Create a heatmap showing all positive or negative correlations higher
# than .5

# %%
cc_corr = cc_holders.corr()

cc_corr_filt = cc_corr[((cc_corr >= .5) | (cc_corr <= -.5))]
plt.figure(figsize=(30,10))
sns.heatmap(cc_corr_filt, annot=True, cmap="Reds")
plt.show()

# %% [markdown]
# What do you observe? What conclusions can you draw from looking at the correlations, and how would that influence a principal components analysis routine? Why do we do Principal Components Analysis?

# %% [markdown]
# 2.8 Examine the discrete distributions of each feature column

# %%
sns.set(rc={'figure.figsize':(20, 15)})
dists = cc_holders.hist(bins=20, color='blue')

# %% [markdown]
# What can you conclude about the distributions of the variables in the data set? In 3-4 sentences, describe methods of handling outliers following the lecture notes.

# %% [markdown]
# 2.9
# *Your answer here*

# %% [markdown]
# 2.10 Examine the data set for missing values

# %%
cc_holders.isna().sum().sort_values(ascending=False)
# Out:
# MINIMUM_PAYMENTS                    313
# CREDIT_LIMIT                          1
# CUST_ID                               0
# BALANCE                               0
# PRC_FULL_PAYMENT                      0
# PAYMENTS                              0
# PURCHASES_TRX                         0
# CASH_ADVANCE_TRX                      0
# CASH_ADVANCE_FREQUENCY                0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_FREQUENCY                   0
# CASH_ADVANCE                          0
# INSTALLMENTS_PURCHASES                0
# ONEOFF_PURCHASES                      0
# PURCHASES                             0
# BALANCE_FREQUENCY                     0
# TENURE                                0
# dtype: int64

# %% [markdown]
# 2.11 Is it reasonable to fill missing values with the median? If so, fill the missing values with the median.

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# 2.12 Check if there are any missing values left

# %%
# Your code here

# %% [markdown]
# 2.13 Drop the CUST_ID column. And why do we do so?
#
# *Your answer here*

# %%
# Your code here

# %% [markdown]
# 2.14 Using the standard scaler, scale the data. Again, why do we do so?
#
# *Your answer here*

# %%
# Your code here

# %% [markdown]
# 2.15 By doing PCA, naturally, we can explain more variance if we allow more components.
#
# Plot the explained variance over the number of components and decide on a reasonable number of components.

# %%
# Your code here

# %% [markdown]
# 2.16 Perform PCA with your chosen number of components and print out the explained variances by each component. When looking back at our EDA, why do we need so many components?

# %%
# Your code here

# %% [markdown]
# 2.17 Plot the observations following PC1 and PC2

# %%
# Your code here

# %% [markdown]
# 2.18 You have learnt in class, that a well-known measure to find a good number of clusters is Inertia. Following the lecture notes, plot the inertia graph for 1-19 clusters

# %%
# Your code here

# %%
# The code for the plot here

# %% [markdown]
# 2.19 Using inertia, we have found the right number of clusters for our use case. Now fit the model and plot the outcome.

# %%
# Your code here

# %%
# Your code here

# %%
# Print out the clusters

# %%
# Plot the outcome

# %% [markdown]
# # 3. Your individual project proposal
#
# Please follow the **FRAMING THE ML PROBLEM** workflow as discussed in Lecture 2
