# %% [markdown]
# # LSTM model of StockData
#
# [Intro to LSTM](https://machinelearningmastery.com/gentle-introduction-long-short-term-memory-networks-experts/)
#
# In this notebook we will go through a basic Long Short Term Memory (LSTM) model for time series. The notebooks does the following things:
# * First load in the data. The preproccessing only consist of normalization and the creation of windows.
# * Creation of the LSTM model
# * Training the LSTM model
# * Testing the LSTM model with 1 time step and with 1 window

# %% [markdown]
# ## Importing libraries and loading in the data

# %% [markdown]
# ### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import re
import math

# %%
import matplotlib.pyplot as plt
import statsmodels.tsa.seasonal as smt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
import datetime as dt
from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error
import plotly
import os
from subprocess import check_output

# import the relevant Keras modules
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %% [markdown]
# ### 1) Loading in the data
#
# Select a stock or ETF for this HW from the ones available.

# %%
filename = "ETFs\\adre.us.txt"#"<insert file name>"
print(filename)

df = pd.read_csv(filename, sep=",")
df['Label'] = filename
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
# ETFs\adre.us.txt
#         Date    Open    High     Low   Close  Volume  OpenInt  \
# 0 2005-02-25  19.065  19.416  19.065  19.416   72019        0
# 1 2005-02-28  20.172  20.172  19.312  19.380  101346        0
# 2 2005-03-01  19.798  19.798  19.209  19.268   53671        0
# 3 2005-03-02  19.109  19.195  19.042  19.160   23894        0
# 4 2005-03-03  19.744  19.744  19.127  19.187   28870        0
#
#               Label
# 0  ETFs\adre.us.txt
# 1  ETFs\adre.us.txt
# 2  ETFs\adre.us.txt
# 3  ETFs\adre.us.txt
# 4  ETFs\adre.us.txt

# %% [markdown]
# ### Visualize the data
#
# Plotly is a nice visualization library that has some interactive plot options.

# %%
r = lambda: random.randint(0,255)
traces = []

#for df in data:
clr = str(r()) + str(r()) + str(r())
df = df.sort_values('Date')
label = df['Label'].iloc[0]

trace = plotly.graph_objs.Scattergl(
    x=df['Date'],
    y=df['Close']#,mode='line',line=dict(color = "blue")
)
traces.append(trace)
    
layout = plotly.graph_objs.Layout(
    title='Plot '+label.split(sep='.')[0].upper(),
)
fig = plotly.graph_objs.Figure(data=traces, layout=layout)

plotly.offline.init_notebook_mode(connected=True)
plotly.offline.iplot(fig, filename='dataplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c2a8ee40-5ab6-4d01-aa07-4c3142bfeec0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2a8ee40-5ab6-4d01-aa07-4c3142bfeec0")) {                    Plotly.newPlot(                        "c2a8ee40-5ab6-4d01-aa07-4c3142bfeec0",                        [{"x":["2005-02-25T00:00:00","2005-02-28T00:00:00","2005-03-01T00:00:00","2005-03-02T00:00:00","2005-03-03T00:00:00","2005-03-04T00:00:00","2005-03-07T00:00:00","2005-03-08T00:00:00","2005-03-09T00:00:00","2005-03-10T00:00:00","2005-03-11T00:00:00","2005-03-14T00:00:00","2005-03-15T00:00:00","2005-03-16T00:00:00","2005-03-17T00:00:00","2005-03-18T00:00:00","2005-03-21T00:00:00","2005-03-22T00:00:00","2005-03-23T00:00:00","2005-03-24T00:00:00","2005-03-28T00:00:00","2005-03-29T00:00:00","2005-03-30T00:00:00","2005-03-31T00:00:00","2005-04-01T00:00:00","2005-04-04T00:00:00","2005-04-05T00:00:00","2005-04-06T00:00:00","2005-04-07T00:00:00","2005-04-08T00:00:00","2005-04-11T00:00:00","2005-04-12T00:00:00","2005-04-13T00:00:00","2005-04-14T00:00:00","2005-04-15T00:00:00","2005-04-18T00:00:00","2005-04-19T00:00:00","2005-04-20T00:00:00","2005-04-21T00:00:00","2005-04-22T00:00:00","2005-04-25T00:00:00","2005-04-26T00:00:00","2005-04-27T00:00:00","2005-04-28T00:00:00","2005-04-29T00:00:00","2005-05-02T00:00:00","2005-05-03T00:00:00","2005-05-04T00:00:00","2005-05-05T00:00:00","2005-05-06T00:00:00","2005-05-09T00:00:00","2005-05-10T00:00:00","2005-05-11T00:00:00","2005-05-12T00:00:00","2005-05-13T00:00:00","2005-05-16T00:00:00","2005-05-17T00:00:00","2005-05-18T00:00:00","2005-05-19T00:00:00","2005-05-20T00:00:00","2005-05-23T00:00:00","2005-05-24T00:00:00","2005-05-25T00:00:00","2005-05-26T00:00:00","2005-05-27T00:00:00","2005-05-31T00:00:00","2005-06-01T00:00:00","2005-06-02T00:00:00","2005-06-03T00:00:00","2005-06-06T00:00:00","2005-06-07T00:00:00","2005-06-08T00:00:00","2005-06-09T00:00:00","2005-06-10T00:00:00","2005-06-13T00:00:00","2005-06-14T00:00:00","2005-06-15T00:00:00","2005-06-16T00:00:00","2005-06-17T00:00:00","2005-06-20T00:00:00","2005-06-21T00:00:00","2005-06-22T00:00:00","2005-06-23T00:00:00","2005-06-24T00:00:00","2005-06-27T00:00:00","2005-06-28T00:00:00","2005-06-29T00:00:00","2005-06-30T00:00:00","2005-07-01T00:00:00","2005-07-05T00:00:00","2005-07-06T00:00:00","2005-07-07T00:00:00","2005-07-08T00:00:00","2005-07-11T00:00:00","2005-07-12T00:00:00","2005-07-13T00:00:00","2005-07-14T00:00:00","2005-07-15T00:00:00","2005-07-18T00:00:00","2005-07-19T00:00:00","2005-07-20T00:00:00","2005-07-21T00:00:00","2005-07-22T00:00:00","2005-07-25T00:00:00","2005-07-26T00:00:00","2005-07-27T00:00:00","2005-07-28T00:00:00","2005-07-29T00:00:00","2005-08-01T00:00:00","2005-08-02T00:00:00","2005-08-03T00:00:00","2005-08-04T00:00:00","2005-08-05T00:00:00","2005-08-08T00:00:00","2005-08-09T00:00:00","2005-08-10T00:00:00","2005-08-11T00:00:00","2005-08-12T00:00:00","2005-08-15T00:00:00","2005-08-16T00:00:00","2005-08-17T00:00:00","2005-08-18T00:00:00","2005-08-19T00:00:00","2005-08-22T00:00:00","2005-08-23T00:00:00","2005-08-24T00:00:00","2005-08-25T00:00:00","2005-08-26T00:00:00","2005-08-29T00:00:00","2005-08-30T00:00:00","2005-08-31T00:00:00","2005-09-01T00:00:00","2005-09-02T00:00:00","2005-09-06T00:00:00","2005-09-07T00:00:00","2005-09-08T00:00:00","2005-09-09T00:00:00","2005-09-12T00:00:00","2005-09-13T00:00:00","2005-09-14T00:00:00","2005-09-15T00:00:00","2005-09-16T00:00:00","2005-09-19T00:00:00","2005-09-20T00:00:00","2005-09-21T00:00:00","2005-09-22T00:00:00","2005-09-23T00:00:00","2005-09-26T00:00:00","2005-09-27T00:00:00","2005-09-28T00:00:00","2005-09-29T00:00:00","2005-09-30T00:00:00","2005-10-03T00:00:00","2005-10-04T00:00:00","2005-10-05T00:00:00","2005-10-06T00:00:00","2005-10-07T00:00:00","2005-10- ...

# %% [markdown]
# ### 2) Creating windows and normalizing the data
#
# The default window here is 10. The final question will ask you to consider this parameter in your final analysis and how it might impact your results.

# %%
window_len = 10

#Create a data point (i.e. a date) which splits the training and testing set
split_date = list(df["Date"][-(2*window_len+1):])[0]
print("split_date:",split_date)


#Split the training and test set
training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
test_set = test_set.drop(['Date','Label','OpenInt'], 1)

#Create windows for training
LSTM_training_inputs = []
for i in range(len(training_set)-window_len):
    temp_set = training_set[i:(i+window_len)].copy()
    
    for col in list(temp_set):
        temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1
    
    LSTM_training_inputs.append(temp_set)
LSTM_training_inputs
LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
LSTM_training_inputs = np.array(LSTM_training_inputs)

# Create windows for testing
LSTM_test_inputs = []
for i in range(len(test_set)-window_len):
    temp_set = test_set[i:(i+window_len)].copy()
    
    for col in list(temp_set):
        temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1
    
    LSTM_test_inputs.append(temp_set)
LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
#            Open      High       Low     Close    Volume
#  997   0.000000  0.000000  0.000000  0.000000  0.000000
#  998  -0.033536 -0.016844 -0.018077 -0.005128  0.101706
#  999  -0.007651 -0.006401  0.009670  0.002479 -0.173213
#  1000 -0.049815 -0.057186 -0.046304 -0.063205  0.349841
#  1001 -0.056743 -0.062955 -0.058414 -0.062479 -0.097095
#  1002 -0.061376 -0.041816 -0.056628 -0.074487 -0.178690
#  1003 -0.097462 -0.094117 -0.089907 -0.089359  0.450422
#  1004 -0.076253 -0.084390 -0.106896 -0.116239  0.003217
#  1005 -0.128151 -0.093780 -0.106503 -0.087906  0.316221
#  1006 -0.100055 -0.090496 -0.095004 -0.093718 -0.201040,
#            Open      High       Low     Close    Volume
#  998   0.000000  0.000000  0.000000  0.000000  0.000000
#  999   0.026783  0.010622  0.028258  0.007646 -0.249539
#  1000 -0.016844 -0.041033 -0.028746 -0.058376  0.225229
#  1001 -0.024013 -0.046901 -0.041079 -0.057646 -0.180448
#  1002 -0.028806 -0.025399 -0.039260 -0.069716 -0.254510
#  1003 -0.066145 -0.078597 -0.073152 -0.084665  0.316524
#  1004 -0.044199 -0.068703 -0.090453 -0.111684 -0.089397
#  1005 -0.097898 -0.078254 -0.090054 -0.083204  0.194712
#  1006 -0.068828 -0.074913 -0.078343 -0.089046 -0.274797
#  1007 -0.058009 -0.068703 -0.064103 -0.093771 -0.030568,
#            Open      High       Low     Close    Volume
#  999   0.000000  0.000000  0.000000  0.000000  0.000000
#  1000 -0.042489 -0.051113 -0.055438 -0.065521  0.632635
#  1001 -0.049471 -0.056919 -0.067432 -0.064797  0.092065
#  1002 -0.054140 -0.035643 -0.065663 -0.076776 -0.006624
#  1003 -0.090504 -0.088281 -0.098624 -0.091611  0.754288
#  1004 -0.069131 -0.078491 -0.115449 -0.118424  0.213392
#  1005 -0.121429 -0.087942 -0.115061 -0.090161  0.591972
#  1006 -0.093117 -0.084637 -0.103671 -0.095959 -0.033657
#  1007 -0.082580 -0.078491 -0.089823 -0.100648  0.291782
#  1008 -0.103311 -0.099767 -0.112818 -0.109728  0.371357,
#  ...]

# %% [markdown]
# ## 3) LSTM model definition
#
# LSTM's have a set of parameters that can be tuned to your data set. Consider these inputs: **activation function, loss function, dropout rate, optimizer, nn layers/architecture** and review your options in the documentation.
#
# [Keras Docs](https://keras.io/api/layers/recurrent_layers/lstm/)

# %%
def build_model(inputs, output_size, neurons, activ_func="linear",
                dropout=0.10, loss="mae", optimizer="adam"):
    
    model = Sequential()

    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %% [markdown]
# ## 4) Training of the LSTM model
#
# Just like most ML models choosing a stopping condition is important. Here we use **Epochs** or iterations to set this stopping condition where we also monitor the loss at each step. Consider **Epochs** as a parameter to adjust.

# %%
# initialise model architecture
nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = 32)
# model output is next price normalised to 10th previous closing price
# train model on data
# note: eth_history contains information on the training error per epoch
nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                            epochs=5, batch_size=1, verbose=2, shuffle=True)
# Out:
# Epoch 1/5
# 3170/3170 - 13s - loss: 0.0280 - 13s/epoch - 4ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0170 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0148 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step

# %% [markdown]
# ### Plot of prediction of one data point ahead
# As can be seen in the plot, one step prediction is not bad. The scale is a bit off, because the data is normalized.

# %%
plt.plot(LSTM_test_outputs, label = "actual")
plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
print('The Mean Absolute Error is: {}'.format(MAE))
# Out:
# The Mean Absolute Error is: 0.005727246911902204

# %% [markdown]
# ### Prediction of one window (n steps) ahead
# As can be seen in the plot below, the performance degrades when predicting multiple time points ahead. However, compered to something like linear regression the performance is better.

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

predictions = predict_sequence_full(nn_model, LSTM_test_inputs, 10)

plt.plot(LSTM_test_outputs, label="actual")
plt.plot(predictions, label="predicted")
plt.legend()
plt.show()
MAE = mean_absolute_error(LSTM_test_outputs, predictions)
print('The Mean Absolute Error is: {}'.format(MAE))
# Out:
# The Mean Absolute Error is: 0.005198429365436847

# %% [markdown]
# ## Conclusion
#
# For this HW your task is to select a stock or ETF from the provided folder. You will run the code above with the default parameters and understand the logic and flow of the program. Once you are confident the code runs you are to test different parameter settings. You are to report the best set of parameters that you find and explain the importance of each parameter and how it impacts the training of the model. To best know how much to adjust and how to interpret the impacts I suggest changing one parameter at a at a time. This is a manual grid search you are performing so that you can become familiar with each parameter. In the future you can have grid search algorithms find the best set for you.
#
# For each define the parameter and it's impact to the model. Report the set of values tested and the best parameter setting you found for each.
#
# 1) Window Length
# 2) LSTM Parameter: activation function
# 3) LSTM Parameter: loss function
# 4) LSTM Parameter: dropout rate
# 5) LSTM Parameter: optimizer
# 6) LSTM Parameter: nn layers/architecture
# 7) Epochs

# %% [markdown]
# The last cell has the questions 1-7 which expects a two part response, 2.pts each question, 1pt for the explanation of the parameter and 1 point for set of values tested with the best value for that particular parameters, this can be reported as an optimal set of parameters at the end. The 8th quest is submitted separately and asks you to perform back propagation on a simple NN for the final 1 pt. In all there are 15 points possible. Please download this notebook, import it into your workspace, download the stock or EFT in the files. You need to select one to train the NN on. Your completed HW should be a notebook with the optimal set of parameters and your answers in the last cell as markdown syntax. Then download the back propagation document and submit that answer as a separate document.

# %% [markdown]
# # Here are my answers to the above questions

# %%
filename = "ETFs\\adre.us.txt"
df = pd.read_csv(filename, sep=",")
df['Label'] = filename
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date    Open    High     Low   Close  Volume  OpenInt  \
# 0 2005-02-25  19.065  19.416  19.065  19.416   72019        0
# 1 2005-02-28  20.172  20.172  19.312  19.380  101346        0
# 2 2005-03-01  19.798  19.798  19.209  19.268   53671        0
# 3 2005-03-02  19.109  19.195  19.042  19.160   23894        0
# 4 2005-03-03  19.744  19.744  19.127  19.187   28870        0
#
#               Label
# 0  ETFs\adre.us.txt
# 1  ETFs\adre.us.txt
# 2  ETFs\adre.us.txt
# 3  ETFs\adre.us.txt
# 4  ETFs\adre.us.txt

# %%
def build_model(inputs, output_size, neurons, activ_func="linear",
                dropout=0.10, loss="mae", optimizer="adam"):
    
    model = Sequential()

    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 tf.config.experimental.set_memory_growth(tf.config.experimental.list_physical_devices("GPU").physical_device[0], True)
#
# AttributeError: 'list' object has no attribute 'physical_device'

# %% [markdown]
# ## Window Length

# %%
window_len_lst = list(range(1, 20))
window_mae_dic = {}

for window_len in window_len_lst:
    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    window_mae_dic[window_len] = MAE
window_result = pd.DataFrame(window_result.values(), window_result.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-11-08 00:00:00
# Epoch 1/5
# 3197/3197 - 7s - loss: 0.0125 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3197/3197 - 6s - loss: 0.0124 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3197/3197 - 5s - loss: 0.0124 - 5s/epoch - 2ms/step
# Epoch 4/5
# 3197/3197 - 6s - loss: 0.0124 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3197/3197 - 6s - loss: 0.0124 - 6s/epoch - 2ms/step
# split_date: 2017-11-06 00:00:00
# Epoch 1/5
# 3194/3194 - 7s - loss: 0.0165 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3194/3194 - 5s - loss: 0.0136 - 5s/epoch - 2ms/step
# Epoch 3/5
# 3194/3194 - 5s - loss: 0.0131 - 5s/epoch - 2ms/step
# Epoch 4/5
# 3194/3194 - 6s - loss: 0.0129 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3194/3194 - 6s - loss: 0.0129 - 6s/epoch - 2ms/step
# split_date: 2017-11-02 00:00:00
# Epoch 1/5
# 3191/3191 - 7s - loss: 0.0193 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3191/3191 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3191/3191 - 7s - loss: 0.0135 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3191/3191 - 6s - loss: 0.0132 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3191/3191 - 6s - loss: 0.0131 - 6s/epoch - 2ms/step
# split_date: 2017-10-31 00:00:00
# Epoch 1/5
# 3188/3188 - 8s - loss: 0.0195 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3188/3188 - 6s - loss: 0.0145 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3188/3188 - 6s - loss: 0.0137 - 6s/epoch - 2ms/step
# Epoch 4/5
# 3188/3188 - 7s - loss: 0.0134 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3188/3188 - 7s - loss: 0.0134 - 7s/epoch - 2ms/step
# split_date: 2017-10-27 00:00:00
# Epoch 1/5
# 3185/3185 - 8s - loss: 0.0212 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3185/3185 - 8s - loss: 0.0150 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3185/3185 - 8s - loss: 0.0138 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3185/3185 - 6s - loss: 0.0136 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3185/3185 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# split_date: 2017-10-25 00:00:00
# Epoch 1/5
# 3182/3182 - 8s - loss: 0.0227 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3182/3182 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3182/3182 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3182/3182 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3182/3182 - 7s - loss: 0.0135 - 7s/epoch - 2ms/step
# split_date: 2017-10-23 00:00:00
# Epoch 1/5
# 3179/3179 - 8s - loss: 0.0251 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3179/3179 - 7s - loss: 0.0158 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3179/3179 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3179/3179 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3179/3179 - 7s - loss: 0.0136 - 7s/epoch - 2ms/step
# split_date: 2017-10-19 00:00:00
# Epoch 1/5
# 3176/3176 - 8s - loss: 0.0220 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3176/3176 - 7s - loss: 0.0155 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3176/3176 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3176/3176 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3176/3176 - 7s - loss: 0.0136 - 7s/epoch - 2ms/step
# split_date: 2017-10-17 00:00:00
# Epoch 1/5
# 3173/3173 - 8s - loss: 0.0246 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3173/3173 - 7s - loss: 0.0157 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3173/3173 - 8s - loss: 0.0144 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3173/3173 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3173/3173 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0229 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0158 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0144 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0142 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0138 - 8s/epoch - 3ms/step
# split_date: 2017-10-11 00:00:00
# Epoch 1/5
# 3167/3167 - 8s - loss: 0.0261 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3167/3167 - 8s - loss: 0.0165 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3167/3167 - 8s - loss: 0.0147 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3167/3167 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3167/3167 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-09 00:00:00
# Epoch 1/5
# 3164/3164 - 9s - loss: 0.0233 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3164/3164 - 7s - loss: 0.0161 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3164/3164 - 7s - loss: 0.0147 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3164/3164 - 8s - loss: 0.0141 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3164/3164 - 8s - loss: 0.0140 - 8s/epoch - 3ms/step
# split_date: 2017-10-05 00:00:00
# Epoch 1/5
# 3161/3161 - 8s - loss: 0.0234 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3161/3161 - 7s - loss: 0.0164 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3161/3161 - 7s - loss: 0.0147 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3161/3161 - 8s - loss: 0.0143 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3161/3161 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# split_date: 2017-10-03 00:00:00
# Epoch 1/5
# 3158/3158 - 8s - loss: 0.0228 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3158/3158 - 7s - loss: 0.0159 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3158/3158 - 7s - loss: 0.0146 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3158/3158 - 8s - loss: 0.0143 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3158/3158 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# split_date: 2017-09-29 00:00:00
# Epoch 1/5
# 3155/3155 - 8s - loss: 0.0249 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3155/3155 - 7s - loss: 0.0165 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3155/3155 - 7s - loss: 0.0151 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3155/3155 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3155/3155 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# split_date: 2017-09-27 00:00:00
# Epoch 1/5
# 3152/3152 - 9s - loss: 0.0245 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3152/3152 - 7s - loss: 0.0167 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3152/3152 - 7s - loss: 0.0150 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3152/3152 - 8s - loss: 0.0146 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3152/3152 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# split_date: 2017-09-25 00:00:00
# Epoch 1/5
# 3149/3149 - 8s - loss: 0.0233 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3149/3149 - 8s - loss: 0.0164 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3149/3149 - 7s - loss: 0.0151 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3149/3149 - 7s - loss: 0.0145 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3149/3149 - 8s - loss: 0.0141 - 8s/epoch - 2ms/step
# split_date: 2017-09-21 00:00:00
# Epoch 1/5
# 3146/3146 - 9s - loss: 0.0258 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3146/3146 - 8s - loss: 0.0174 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3146/3146 - 8s - loss: 0.0156 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3146/3146 - 8s - loss: 0.0148 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3146/3146 - 8s - loss: 0.0144 - 8s/epoch - 2ms/step
# split_date: 2017-09-19 00:00:00
# Epoch 1/5
# 3143/3143 - 10s - loss: 0.0267 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3143/3143 - 8s - loss: 0.0173 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3143/3143 - 9s - loss: 0.0156 - 9s/epoch - 3ms/step
# Epoch 4/5
# 3143/3143 - 9s - loss: 0.0147 - 9s/epoch - 3ms/step
# Epoch 5/5
# 3143/3143 - 9s - loss: 0.0143 - 9s/epoch - 3ms/step

# %%
print(window_result.loc[window_result["MAE"] == window_result["MAE"].min()])
window_result.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The model parameter window denotes the number of days we use to trace back the prices, which hence represents the histrorical performance of the underlying asset.
#
# It can be shown that using window = 1 would be the best choice with lowest mean absolute error, the result may due to the fact that, the price variation would not be so large between two consecutive trading days. We can observe from the plot that, the MAE firstly gets higher, then drops down and pulls up again.

# %% [markdown]
# ## LSTM Parameter: activation function

# %%
activation_lst = ["relu", "sigmoid", "softmax", "softplus", "softsign", 
                  "tanh", "selu", "elu", "exponential", "linear"]
activation_dic = {}

window_len = 10
for activation in activation_lst:
    def this_build_model(inputs, output_size, neurons, activ_func=activation, 
                         dropout=0.10, loss="mae", optimizer="adam"):
        model = Sequential()

        model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
        model.add(Dropout(dropout))
        model.add(Dense(units=output_size))
        model.add(Activation(activ_func))

        model.compile(loss=loss, optimizer=optimizer)
        return model

    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = this_build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    activation_dic[activation] = MAE
activation_result = pd.DataFrame(activation_dic.values(), activation_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0364 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0364 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0364 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0364 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0364 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0413 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0287 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0270 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0260 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0256 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.9962 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.9962 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.9962 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.9962 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.9962 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0432 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0287 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0272 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0263 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0257 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0225 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0157 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0230 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0266 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0171 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0152 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0148 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0234 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0160 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0146 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0138 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0485 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0299 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0276 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0266 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0261 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0223 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0159 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0145 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0140 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step

# %%
print(activation_result.loc[activation_result["MAE"] == activation_result["MAE"].min()])
activation_result.plot()
# Out:
#            MAE
# selu  0.004938
# <AxesSubplot:>

# %% [markdown]
# The LSTM parameter activation function is the function we use in every hidden layer node in the model. That is, for each node in our model, the value would be give by $\sigma(w\cdot x + b)$, where $\sigma$ is the activation function. If we use no activation function, the defualt set would be linear. However, a specified activation function type except linear function would introduce non-lineartiy into the model.
#
# We can observe that the ``selu`` activation function has the lowest error, however, it doesn't vary a lot from other activation functions except for ``softmax``, which has significantly higher error than other activation functions. This is becuase ``softmax`` function is a probabilistic function, and the vector returned by it would sum up to 1.

# %% [markdown]
# ## LSTM Parameter: loss function

# %%
loss_lst = [tf.keras.losses.MeanSquaredError(), tf.keras.losses.MeanAbsoluteError(), 
           tf.keras.losses.MeanAbsolutePercentageError(), tf.keras.losses.MeanSquaredLogarithmicError(), 
           tf.keras.losses.CosineSimilarity(axis=1), tf.keras.losses.Huber(), tf.keras.losses.LogCosh()]
loss_dic = {}

window_len = 10
for loss in loss_lst:
    def this_build_model(inputs, output_size, neurons, activ_func="linear", 
                         dropout=0.10, loss=loss, optimizer="adam"):
        model = Sequential()

        model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
        model.add(Dropout(dropout))
        model.add(Dense(units=output_size))
        model.add(Activation(activ_func))

        model.compile(loss=loss, optimizer=optimizer)
        return model

    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = this_build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    this_name = re.split("[\s]", re.split("\.", str(loss))[-1])[0]
    loss_dic[this_name] = MAE
loss_result = pd.DataFrame(loss_dic.values(), loss_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0013 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 5.2737e-04 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 4.7403e-04 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 4.2382e-04 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 4.0511e-04 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0231 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0157 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 238168.4688 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 263271.9688 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 188320.5469 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 247032.2812 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 111692.6875 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 5.2068e-04 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 2.5867e-04 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 1.9786e-04 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 1.7619e-04 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 1.5894e-04 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: -1.0410e-01 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: -1.3312e-01 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: -1.3312e-01 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: -1.3312e-01 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: -1.3312e-01 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 6.0328e-04 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 3.0522e-04 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 2.3359e-04 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 2.1233e-04 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 2.0425e-04 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0010 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 3.2983e-04 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 2.7629e-04 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 2.1561e-04 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 2.0879e-04 - 8s/epoch - 3ms/step

# %%
print(loss_result.loc[loss_result["MAE"] == loss_result["MAE"].min()])
loss_result.plot(rot=90)
# Out:
#               MAE
# LogCosh  0.005025
# <AxesSubplot:>

# %% [markdown]
# The loss function is the function that the model would seek to minimize during training. Here, the mean absolute error function would give us the lowest error value, however, this is becuase we used different measurement.

# %% [markdown]
# ## LSTM Parameter: dropout rate

# %%
dropout_lst = np.arange(0, 1, 0.05)
dropout_dic = {}

for dropout in dropout_lst:
    def this_build_model(inputs, output_size, neurons, activ_func="linear", 
                         dropout=dropout, loss="mae", optimizer="adam"):
        model = Sequential()

        model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
        model.add(Dropout(dropout))
        model.add(Dense(units=output_size))
        model.add(Activation(activ_func))

        model.compile(loss="mae", optimizer=optimizer)
        return model

    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = this_build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    dropout_dic[dropout] = MAE
dropout_result = pd.DataFrame(dropout_dic.values(), dropout_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0207 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0160 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0145 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 6s - loss: 0.0140 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 6s - loss: 0.0137 - 6s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0218 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 6s - loss: 0.0155 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 6s - loss: 0.0138 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 6s - loss: 0.0136 - 6s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0219 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0155 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0144 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0139 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0137 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0224 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0158 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0146 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0141 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0232 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0161 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0147 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0145 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0142 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0243 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0162 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0153 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0146 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0146 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0290 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0170 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0158 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0147 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0149 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0267 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0171 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 9s - loss: 0.0158 - 9s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 9s - loss: 0.0151 - 9s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 9s - loss: 0.0146 - 9s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0277 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0176 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0158 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0155 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0154 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0283 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0179 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0168 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0159 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0312 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0185 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0168 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0160 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 9s - loss: 0.0158 - 9s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0313 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0186 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 9s - loss: 0.0173 - 9s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0165 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0159 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0329 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0191 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0177 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0171 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0167 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0396 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0201 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0188 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0177 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0174 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0441 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0204 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0192 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0181 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0177 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0407 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0222 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0200 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0191 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0183 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0419 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0226 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0207 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0202 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 9s - loss: 0.0196 - 9s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 10s - loss: 0.0459 - 10s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0242 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0222 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0213 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0208 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0558 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0261 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0249 - 8s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0238 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0237 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0812 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0321 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0283 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0279 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0268 - 7s/epoch - 2ms/step

# %%
print(dropout_result.loc[dropout_result["MAE"] == dropout_result["MAE"].min()])
dropout_result.plot()
# Out:
#            MAE
# 0.65  0.004633
# <AxesSubplot:>

# %% [markdown]
# Dropout regularization is the fraction that we randomly "dropping out" unit activations in a single network for each single gradient step, the higher the dropout is, the stronger the regularization the it performs.
#
# From the output, we can observe that with the increase of the dropout, the error firstly reduced and then increased, and the approximate minimum was reached when $\text{dropout} \approx 0.65$.

# %% [markdown]
# ## LSTM Parameter: optimizer

# %%
optimizer_lst = ["sgd", "rmsprop", "adam", "adadelta", "adagrad", "adamax", "nadam", "ftrl"]
optimizer_dic = {}

for optimizer in optimizer_lst:
    def this_build_model(inputs, output_size, neurons, activ_func="linear", 
                         dropout=0.10, loss="mae", optimizer=optimizer):
        model = Sequential()

        model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
        model.add(Dropout(dropout))
        model.add(Dense(units=output_size))
        model.add(Activation(activ_func))

        model.compile(loss="mae", optimizer=optimizer)
        return model

    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = this_build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    optimizer_dic[optimizer] = MAE
optimizer_result = pd.DataFrame(optimizer_dic.values(), optimizer_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0361 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0258 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0232 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0218 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0215 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 11s - loss: 0.0239 - 11s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 9s - loss: 0.0155 - 9s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 9s - loss: 0.0144 - 9s/epoch - 3ms/step
# Epoch 4/5
# 3170/3170 - 9s - loss: 0.0140 - 9s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0138 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0213 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0156 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.1078 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0863 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0724 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0625 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0552 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0508 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0402 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0343 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0330 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0310 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0210 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0183 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0168 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0155 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 13s - loss: 0.0247 - 13s/epoch - 4ms/step
# Epoch 2/5
# 3170/3170 - 11s - loss: 0.0160 - 11s/epoch - 4ms/step
# Epoch 3/5
# 3170/3170 - 12s - loss: 0.0146 - 12s/epoch - 4ms/step
# Epoch 4/5
# 3170/3170 - 12s - loss: 0.0140 - 12s/epoch - 4ms/step
# Epoch 5/5
# 3170/3170 - 14s - loss: 0.0138 - 14s/epoch - 4ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step

# %%
print(optimizer_result.loc[optimizer_result["MAE"] == optimizer_result["MAE"].min()])
optimizer_result.plot(rot=90)
# Out:
#             MAE
# nadam  0.006117
# <AxesSubplot:>

# %% [markdown]
# An optimizer is one of the two arguments required for compiling our model. Here, we would choose nadam as our optimizer since it generates lowest error.

# %% [markdown]
# ## LSTM Parameter: nn layers/architecture

# %%
neurons_lst = np.arange(32, 168, 8)
neurons_dic = {}

for neurons in neurons_lst:
    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = build_model(LSTM_training_inputs, output_size=1, neurons = neurons)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=5, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    neurons_dic[neurons] = MAE
neurons_result = pd.DataFrame(neurons_dic.values(), neurons_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0241 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0158 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0145 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0224 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0156 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0203 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 6s - loss: 0.0151 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 6s - loss: 0.0138 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0227 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0158 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0137 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0209 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0155 - 8s/epoch - 3ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 6s - loss: 0.0138 - 6s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0226 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0158 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0147 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0228 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0156 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 6s - loss: 0.0144 - 6s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0209 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0209 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0155 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0143 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 9s - loss: 0.0140 - 9s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0229 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0155 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 8s - loss: 0.0145 - 8s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0216 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 6s - loss: 0.0153 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 6s - loss: 0.0144 - 6s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0142 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 8s - loss: 0.0138 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0208 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0145 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0139 - 8s/epoch - 3ms/step
# Epoch 5/5
# 3170/3170 - 9s - loss: 0.0139 - 9s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0218 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0152 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0145 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0138 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0212 - 8s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0153 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0140 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0205 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 7s - loss: 0.0151 - 7s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0144 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0141 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 9s - loss: 0.0210 - 9s/epoch - 3ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0152 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0146 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 7s - loss: 0.0143 - 7s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0139 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 7s - loss: 0.0212 - 7s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 6s - loss: 0.0153 - 6s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 6s - loss: 0.0143 - 6s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 6s - loss: 0.0141 - 6s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 6s - loss: 0.0137 - 6s/epoch - 2ms/step

# %%
print(neurons_result.loc[neurons_result["MAE"] == neurons_result["MAE"].min()])
neurons_result.plot()
# Out:
#          MAE
# 96  0.005046
# <AxesSubplot:>

# %% [markdown]
# The	NN architecture	is made of neurons, which are simulations of human brain, which is a process that generates some inputs, then converts and transfers them to the node (activation function) and then returns an output NN architecture also contains the bias, transfer function and activation function.
#
# Here, I tested different NN architectures with number of neurons from 32 to 168, and concluded that we would get the lowest error when the number is 96.

# %% [markdown]
# ## Epochs

# %%
epochs_lst = range(5, 20)
epochs_dic = {}

for epochs in epochs_lst:
    def this_build_model(inputs, output_size, neurons, activ_func="linear", 
                         dropout=0.10, loss="mae", optimizer=optimizer):
        model = Sequential()

        model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
        model.add(Dropout(dropout))
        model.add(Dense(units=output_size))
        model.add(Activation(activ_func))

        model.compile(loss="mae", optimizer=optimizer)
        return model

    split_date = list(df["Date"][-(2*window_len+1):])[0]
    print("split_date:",split_date)

    #Split the training and test set
    training_set, test_set = df[df['Date'] < split_date], df[df['Date'] >= split_date]
    training_set = training_set.drop(['Date','Label', 'OpenInt'], 1)
    test_set = test_set.drop(['Date','Label','OpenInt'], 1)

    #Create windows for training
    LSTM_training_inputs = []
    for i in range(len(training_set)-window_len):
        temp_set = training_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_training_inputs.append(temp_set)
    LSTM_training_inputs
    LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

    LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
    LSTM_training_inputs = np.array(LSTM_training_inputs)

    # Create windows for testing
    LSTM_test_inputs = []
    for i in range(len(test_set)-window_len):
        temp_set = test_set[i:(i+window_len)].copy()

        for col in list(temp_set):
            temp_set[col] = temp_set[col]/temp_set[col].iloc[0] - 1

        LSTM_test_inputs.append(temp_set)
    LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

    LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
    LSTM_test_inputs = np.array(LSTM_test_inputs)

    # initialise model architecture
    nn_model = this_build_model(LSTM_training_inputs, output_size=1, neurons = 32)
    # model output is next price normalised to 10th previous closing price train model on data
    # note: eth_history contains information on the training error per epoch
    nn_history = nn_model.fit(LSTM_training_inputs, LSTM_training_outputs, 
                                epochs=epochs, batch_size=1, verbose=2, shuffle=True)
    plt.plot(LSTM_test_outputs, label = "actual")
    plt.plot(nn_model.predict(LSTM_test_inputs), label = "predicted")
    plt.legend()
    plt.show()
    MAE = mean_absolute_error(LSTM_test_outputs, nn_model.predict(LSTM_test_inputs))
    epochs_dic[epochs] = MAE
epochs_result = pd.DataFrame(epochs_dic.values(), epochs_dic.keys()).rename(columns={0: "MAE"})
# Out:
# split_date: 2017-10-13 00:00:00
# Epoch 1/5
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 2ms/step
# Epoch 2/5
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 3/5
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/5
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 5/5
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/6
# 3170/3170 - 9s - loss: 0.0360 - 9s/epoch - 3ms/step
# Epoch 2/6
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 3/6
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/6
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 5/6
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 6/6
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/7
# 3170/3170 - 9s - loss: 0.0360 - 9s/epoch - 3ms/step
# Epoch 2/7
# 3170/3170 - 9s - loss: 0.0355 - 9s/epoch - 3ms/step
# Epoch 3/7
# 3170/3170 - 8s - loss: 0.0352 - 8s/epoch - 3ms/step
# Epoch 4/7
# 3170/3170 - 7s - loss: 0.0348 - 7s/epoch - 2ms/step
# Epoch 5/7
# 3170/3170 - 7s - loss: 0.0344 - 7s/epoch - 2ms/step
# Epoch 6/7
# 3170/3170 - 7s - loss: 0.0339 - 7s/epoch - 2ms/step
# Epoch 7/7
# 3170/3170 - 7s - loss: 0.0334 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/8
# 3170/3170 - 10s - loss: 0.0360 - 10s/epoch - 3ms/step
# Epoch 2/8
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 3/8
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 2ms/step
# Epoch 4/8
# 3170/3170 - 7s - loss: 0.0357 - 7s/epoch - 2ms/step
# Epoch 5/8
# 3170/3170 - 7s - loss: 0.0356 - 7s/epoch - 2ms/step
# Epoch 6/8
# 3170/3170 - 7s - loss: 0.0356 - 7s/epoch - 2ms/step
# Epoch 7/8
# 3170/3170 - 7s - loss: 0.0355 - 7s/epoch - 2ms/step
# Epoch 8/8
# 3170/3170 - 7s - loss: 0.0353 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/9
# 3170/3170 - 9s - loss: 0.0368 - 9s/epoch - 3ms/step
# Epoch 2/9
# 3170/3170 - 8s - loss: 0.0352 - 8s/epoch - 2ms/step
# Epoch 3/9
# 3170/3170 - 7s - loss: 0.0344 - 7s/epoch - 2ms/step
# Epoch 4/9
# 3170/3170 - 7s - loss: 0.0338 - 7s/epoch - 2ms/step
# Epoch 5/9
# 3170/3170 - 7s - loss: 0.0333 - 7s/epoch - 2ms/step
# Epoch 6/9
# 3170/3170 - 7s - loss: 0.0325 - 7s/epoch - 2ms/step
# Epoch 7/9
# 3170/3170 - 8s - loss: 0.0318 - 8s/epoch - 3ms/step
# Epoch 8/9
# 3170/3170 - 8s - loss: 0.0312 - 8s/epoch - 3ms/step
# Epoch 9/9
# 3170/3170 - 7s - loss: 0.0302 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/10
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 3ms/step
# Epoch 2/10
# 3170/3170 - 9s - loss: 0.0359 - 9s/epoch - 3ms/step
# Epoch 3/10
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/10
# 3170/3170 - 6s - loss: 0.0359 - 6s/epoch - 2ms/step
# Epoch 5/10
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 6/10
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 7/10
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 8/10
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 9/10
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 10/10
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/11
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 3ms/step
# Epoch 2/11
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 3/11
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 4/11
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 5/11
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 6/11
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 7/11
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 8/11
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 9/11
# 3170/3170 - 7s - loss: 0.0357 - 7s/epoch - 2ms/step
# Epoch 10/11
# 3170/3170 - 7s - loss: 0.0357 - 7s/epoch - 2ms/step
# Epoch 11/11
# 3170/3170 - 7s - loss: 0.0356 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/12
# 3170/3170 - 9s - loss: 0.0360 - 9s/epoch - 3ms/step
# Epoch 2/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 3/12
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 5/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 6/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 7/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 8/12
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 9/12
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 10/12
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 2ms/step
# Epoch 11/12
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 2ms/step
# Epoch 12/12
# 3170/3170 - 7s - loss: 0.0357 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/13
# 3170/3170 - 9s - loss: 0.0360 - 9s/epoch - 3ms/step
# Epoch 2/13
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 3ms/step
# Epoch 3/13
# 3170/3170 - 9s - loss: 0.0357 - 9s/epoch - 3ms/step
# Epoch 4/13
# 3170/3170 - 8s - loss: 0.0357 - 8s/epoch - 3ms/step
# Epoch 5/13
# 3170/3170 - 8s - loss: 0.0355 - 8s/epoch - 2ms/step
# Epoch 6/13
# 3170/3170 - 9s - loss: 0.0354 - 9s/epoch - 3ms/step
# Epoch 7/13
# 3170/3170 - 7s - loss: 0.0352 - 7s/epoch - 2ms/step
# Epoch 8/13
# 3170/3170 - 9s - loss: 0.0351 - 9s/epoch - 3ms/step
# Epoch 9/13
# 3170/3170 - 8s - loss: 0.0348 - 8s/epoch - 3ms/step
# Epoch 10/13
# 3170/3170 - 8s - loss: 0.0346 - 8s/epoch - 2ms/step
# Epoch 11/13
# 3170/3170 - 7s - loss: 0.0342 - 7s/epoch - 2ms/step
# Epoch 12/13
# 3170/3170 - 8s - loss: 0.0338 - 8s/epoch - 3ms/step
# Epoch 13/13
# 3170/3170 - 8s - loss: 0.0333 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/14
# 3170/3170 - 9s - loss: 0.0360 - 9s/epoch - 3ms/step
# Epoch 2/14
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 3/14
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 3ms/step
# Epoch 4/14
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 3ms/step
# Epoch 5/14
# 3170/3170 - 9s - loss: 0.0357 - 9s/epoch - 3ms/step
# Epoch 6/14
# 3170/3170 - 10s - loss: 0.0356 - 10s/epoch - 3ms/step
# Epoch 7/14
# 3170/3170 - 8s - loss: 0.0355 - 8s/epoch - 2ms/step
# Epoch 8/14
# 3170/3170 - 8s - loss: 0.0353 - 8s/epoch - 3ms/step
# Epoch 9/14
# 3170/3170 - 8s - loss: 0.0351 - 8s/epoch - 3ms/step
# Epoch 10/14
# 3170/3170 - 8s - loss: 0.0349 - 8s/epoch - 3ms/step
# Epoch 11/14
# 3170/3170 - 7s - loss: 0.0347 - 7s/epoch - 2ms/step
# Epoch 12/14
# 3170/3170 - 7s - loss: 0.0343 - 7s/epoch - 2ms/step
# Epoch 13/14
# 3170/3170 - 8s - loss: 0.0338 - 8s/epoch - 2ms/step
# Epoch 14/14
# 3170/3170 - 8s - loss: 0.0331 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/15
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 2ms/step
# Epoch 2/15
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 3/15
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 4/15
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 5/15
# 3170/3170 - 7s - loss: 0.0357 - 7s/epoch - 2ms/step
# Epoch 6/15
# 3170/3170 - 7s - loss: 0.0356 - 7s/epoch - 2ms/step
# Epoch 7/15
# 3170/3170 - 9s - loss: 0.0355 - 9s/epoch - 3ms/step
# Epoch 8/15
# 3170/3170 - 8s - loss: 0.0353 - 8s/epoch - 3ms/step
# Epoch 9/15
# 3170/3170 - 7s - loss: 0.0351 - 7s/epoch - 2ms/step
# Epoch 10/15
# 3170/3170 - 7s - loss: 0.0348 - 7s/epoch - 2ms/step
# Epoch 11/15
# 3170/3170 - 9s - loss: 0.0344 - 9s/epoch - 3ms/step
# Epoch 12/15
# 3170/3170 - 8s - loss: 0.0340 - 8s/epoch - 2ms/step
# Epoch 13/15
# 3170/3170 - 8s - loss: 0.0334 - 8s/epoch - 2ms/step
# Epoch 14/15
# 3170/3170 - 7s - loss: 0.0326 - 7s/epoch - 2ms/step
# Epoch 15/15
# 3170/3170 - 8s - loss: 0.0316 - 8s/epoch - 3ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/16
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 3ms/step
# Epoch 2/16
# 3170/3170 - 8s - loss: 0.0356 - 8s/epoch - 2ms/step
# Epoch 3/16
# 3170/3170 - 7s - loss: 0.0354 - 7s/epoch - 2ms/step
# Epoch 4/16
# 3170/3170 - 8s - loss: 0.0352 - 8s/epoch - 2ms/step
# Epoch 5/16
# 3170/3170 - 9s - loss: 0.0349 - 9s/epoch - 3ms/step
# Epoch 6/16
# 3170/3170 - 8s - loss: 0.0347 - 8s/epoch - 2ms/step
# Epoch 7/16
# 3170/3170 - 7s - loss: 0.0343 - 7s/epoch - 2ms/step
# Epoch 8/16
# 3170/3170 - 7s - loss: 0.0340 - 7s/epoch - 2ms/step
# Epoch 9/16
# 3170/3170 - 7s - loss: 0.0336 - 7s/epoch - 2ms/step
# Epoch 10/16
# 3170/3170 - 7s - loss: 0.0330 - 7s/epoch - 2ms/step
# Epoch 11/16
# 3170/3170 - 8s - loss: 0.0325 - 8s/epoch - 2ms/step
# Epoch 12/16
# 3170/3170 - 7s - loss: 0.0319 - 7s/epoch - 2ms/step
# Epoch 13/16
# 3170/3170 - 7s - loss: 0.0312 - 7s/epoch - 2ms/step
# Epoch 14/16
# 3170/3170 - 7s - loss: 0.0304 - 7s/epoch - 2ms/step
# Epoch 15/16
# 3170/3170 - 7s - loss: 0.0294 - 7s/epoch - 2ms/step
# Epoch 16/16
# 3170/3170 - 7s - loss: 0.0283 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/17
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 2/17
# 3170/3170 - 7s - loss: 0.0355 - 7s/epoch - 2ms/step
# Epoch 3/17
# 3170/3170 - 8s - loss: 0.0352 - 8s/epoch - 3ms/step
# Epoch 4/17
# 3170/3170 - 8s - loss: 0.0348 - 8s/epoch - 2ms/step
# Epoch 5/17
# 3170/3170 - 7s - loss: 0.0345 - 7s/epoch - 2ms/step
# Epoch 6/17
# 3170/3170 - 7s - loss: 0.0341 - 7s/epoch - 2ms/step
# Epoch 7/17
# 3170/3170 - 8s - loss: 0.0336 - 8s/epoch - 3ms/step
# Epoch 8/17
# 3170/3170 - 8s - loss: 0.0330 - 8s/epoch - 3ms/step
# Epoch 9/17
# 3170/3170 - 8s - loss: 0.0324 - 8s/epoch - 3ms/step
# Epoch 10/17
# 3170/3170 - 8s - loss: 0.0316 - 8s/epoch - 3ms/step
# Epoch 11/17
# 3170/3170 - 8s - loss: 0.0307 - 8s/epoch - 2ms/step
# Epoch 12/17
# 3170/3170 - 8s - loss: 0.0297 - 8s/epoch - 2ms/step
# Epoch 13/17
# 3170/3170 - 8s - loss: 0.0284 - 8s/epoch - 3ms/step
# Epoch 14/17
# 3170/3170 - 8s - loss: 0.0271 - 8s/epoch - 3ms/step
# Epoch 15/17
# 3170/3170 - 8s - loss: 0.0255 - 8s/epoch - 2ms/step
# Epoch 16/17
# 3170/3170 - 7s - loss: 0.0236 - 7s/epoch - 2ms/step
# Epoch 17/17
# 3170/3170 - 7s - loss: 0.0218 - 7s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/18
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 3ms/step
# Epoch 2/18
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 3ms/step
# Epoch 3/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 5/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 6/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 7/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 8/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 9/18
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 10/18
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 11/18
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 12/18
# 3170/3170 - 8s - loss: 0.0358 - 8s/epoch - 3ms/step
# Epoch 13/18
# 3170/3170 - 9s - loss: 0.0358 - 9s/epoch - 3ms/step
# Epoch 14/18
# 3170/3170 - 8s - loss: 0.0357 - 8s/epoch - 3ms/step
# Epoch 15/18
# 3170/3170 - 8s - loss: 0.0356 - 8s/epoch - 2ms/step
# Epoch 16/18
# 3170/3170 - 8s - loss: 0.0354 - 8s/epoch - 3ms/step
# Epoch 17/18
# 3170/3170 - 8s - loss: 0.0351 - 8s/epoch - 3ms/step
# Epoch 18/18
# 3170/3170 - 8s - loss: 0.0348 - 8s/epoch - 2ms/step
# split_date: 2017-10-13 00:00:00
# Epoch 1/19
# 3170/3170 - 8s - loss: 0.0360 - 8s/epoch - 2ms/step
# Epoch 2/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 3/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 4/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 5/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 6/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 7/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 8/19
# 3170/3170 - 8s - loss: 0.0359 - 8s/epoch - 2ms/step
# Epoch 9/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 10/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 11/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 12/19
# 3170/3170 - 7s - loss: 0.0359 - 7s/epoch - 2ms/step
# Epoch 13/19
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 14/19
# 3170/3170 - 7s - loss: 0.0358 - 7s/epoch - 2ms/step
# Epoch 15/19
# 3170/3170 - 8s - loss: 0.0357 - 8s/epoch - 2ms/step
# Epoch 16/19
# 3170/3170 - 7s - loss: 0.0355 - 7s/epoch - 2ms/step
# Epoch 17/19
# 3170/3170 - 7s - loss: 0.0353 - 7s/epoch - 2ms/step
# Epoch 18/19
# 3170/3170 - 7s - loss: 0.0349 - 7s/epoch - 2ms/step
# Epoch 19/19
# 3170/3170 - 9s - loss: 0.0343 - 9s/epoch - 3ms/step

# %%
print(epochs_result.loc[epochs_result["MAE"] == epochs_result["MAE"].min()])
epochs_result.plot()
# Out:
#          MAE
# 17  0.006059
# <AxesSubplot:>

# %% [markdown]
# In our model, one epoch means that we completed one forward algorithm and one backpropagation. With the increase of the number of epochs, we get better outcomes (lower errors), and then the errors would get higher at some points due to overfitting.
#
# Here, I tested the number of epochs from 5 to 20, and concluded that when $epochs = 17$, we would get a the lowest error significantly, since it is really obvious as we can see in the plot above.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The parameter I choose hence is:
#
# window length = 1
#
# activation function = selu
#
# loss function = mae
#
# dropout rate = 0.65
#
# optimizer = nadam
#
# neurons = 96
#
# epochs = 17

# %% [markdown]
# # Part 2

# %%
def sigmoid(p):
    return 1/(1+math.exp(-p))

def backpropagation(x, y, z, data=np.array([1, 4, 5]), target=np.array([0.1, 0.05]), lr=0.01):
    h_1 = 0.1*x + 0.3*y + 0.5*z + 0.5
    h_2 = 0.2*x + 0.4*y + 0.6*z + 0.5
    h_1, h_2 = sigmoid(h_1), sigmoid(h_2)
    o_1 = 0.7*h_1 + 0.9*h_2 + 0.5
    o_2 = 0.8*h_1 + 0.1*h_2 + 0.5
    o_1, o_2 = sigmoid(o_1), sigmoid(o_2)
    sse = 1/2 * sum((target-np.array([o_1, o_2]))**2)
    partial_sse_o1 = o_1 - target[0]
    partial_sse_o2 = o_2 - target[1]
    partial_o1_n1 = o_1 * (1 - o_1) 
    partial_o2_n2 = o_2 * (1 - o_2)

# %%
# Out:
# array([0.01  , 0.0025])
